# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandushiva2002/simple--python-game-/blob/main/ITEC613_lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Lab 2: Exploratory Data Analysis on Berlin Airbnb Dataset

# %%
# Install necessary libraries (if not already installed)
# !pip install pandas seaborn matplotlib

# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = "listings_berlin-1.csv"
# Ensure this file is uploaded in Colab

# %%
#df = pd.read_csv(file_path)

# %%
# Display basic information
print("Dataset Overview:")
df.info()
print("\nFirst few rows:")
print(df.head())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19095 entries, 0 to 19094
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19095 non-null  int64
#  1   name                            19095 non-null  object
#  2   host_id                         19095 non-null  int64
#  3   host_name                       19095 non-null  object
#  4   neighbourhood_group             19095 non-null  object
#  5   neighbourhood                   19095 non-null  object
#  6   latitude                        19095 non-null  float64
#  7   longitude                       19095 non-null  float64
#  8   room_type                       19095 non-null  object
#  9   price                           19095 non-null  int64
#  10  minimum_nights                  19095 non-null  int64
#  11  number_of_reviews               19095 non-null  int64
# ...

# %% [markdown]
# Task 2.1

# %%
# Task 2.1: Examine the dataset
print("\nTotal number of properties:", len(df))
print("\nColumns in dataset:", df.columns.tolist())
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Total number of properties: 19095
#
# Columns in dataset: ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#
# Missing values:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# Task 2.2

# %%
# Task 2.2: Handle missing data
df["name"].fillna("Unknown", inplace=True)
df["host_name"].fillna("Unknown", inplace=True)
df["last_review"].fillna("No Review", inplace=True)
df["reviews_per_month"].fillna(0, inplace=True)
print("\nMissing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values after handling:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
# <ipython-input-10-ad7e414bfc49>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Task 2.3

# %%
# Task 2.3: Scatter plot of property distribution
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["latitude"], y=df["longitude"], alpha=0.5)
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.title("Property Distribution in Berlin")
plt.show()

# %% [markdown]
# Task 2.4

# %%
# Task 2.4: Histogram of room types
plt.figure(figsize=(8,5))
sns.countplot(x=df["room_type"], palette="viridis")
plt.xlabel("Room Type")
plt.ylabel("Count")
plt.title("Distribution of Room Types")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-12-e34b1c433fa0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["room_type"], palette="viridis")

# %% [markdown]
# Task 3

# %%
# Task 3: Additional Insights
print("\nAdditional Insights:")
print("Price Distribution by Neighborhood:")
print(df.groupby("neighbourhood")["price"].mean().sort_values(ascending=False))
# Out:
# Additional Insights:
# Price Distribution by Neighborhood:
# neighbourhood
# Marzahn-Nord                500.000000
# Haselhorst                  183.333333
# Köpenick-Süd                138.562500
# Rummelsburger Bucht         137.825000
# Kurfürstendamm              137.500000
#                                ...
# Hellersdorf-Ost              35.166667
# Forst Grunewald              35.000000
# Friedrichsfelde Süd          34.323529
# Neu-Hohenschönhausen Süd     27.600000
# Siemensstadt                 27.000000
# Name: price, Length: 138, dtype: float64

# %%
# Save processed dataset
processed_file_path = "processed_listings_berlin.csv"
df.to_csv(processed_file_path, index=False)
print("\nProcessed dataset saved as:", processed_file_path)
# Out:
# Processed dataset saved as: processed_listings_berlin.csv
